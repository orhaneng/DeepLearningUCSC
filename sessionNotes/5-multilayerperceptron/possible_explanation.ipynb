# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 20, 0.1)
y1 = np.sin(x+1)

# %%
plt.plot(x,y1)
plt.show()

# %%
y2 = np.sin(y1+1)
plt.plot(x,y2)
plt.show()

# %%
y3 = np.sin(y2+1)
plt.plot(x,y3)
plt.show()
